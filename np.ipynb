# %%
pip install numpy matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 17.7 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ---------------------------------------- 3.3/3.3 MB 26.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 960.8/960.8 kB 20.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 54.9/54.9 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t=np.linspace(0, 4 * np.pi, 100)

# %%
t
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
import math

# %%
y1 = np.sin(t)
y2 = np.sin(t+np.pi/4)

# %%
plt.plot(t,y1,"-*r", t, y2, "-g")
plt.grid()

# %%
m = np.array([[1,2], [3,4]])
m
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
m = np.random.normal(size=(100,100))
m
# Out:
# array([[-0.43568131,  1.05339138,  0.27200393, ...,  1.0941358 ,
#         -0.04079661, -0.31877287],
#        [-0.30968705,  1.07495575,  0.2669426 , ...,  1.17009822,
#          0.06683751, -0.65811062],
#        [ 1.27676602,  0.92383659,  0.60392088, ..., -0.86461107,
#          1.37774369, -1.60906507],
#        ...,
#        [-0.95352846,  1.33963576,  0.48176553, ...,  1.45224033,
#         -0.19813078, -0.48151837],
#        [-0.90867111, -0.65662148, -0.61440267, ...,  0.92693864,
#          0.46611314,  0.6344977 ],
#        [-0.07027277,  1.53650879, -0.01305569, ...,  0.73581499,
#         -0.66594299, -1.68398171]])

# %%
m = np.random.gamma(0.2, size=(100,100))
plt.imshow(m)

# %%
np.linalg.det(m)
# Out:
# -4.125325165191159e+39

# %%
x = np.linalg.inv(m)

# %%
np.linalg.det(np.matmul(m,x))
# Out:
# 1.000000000000037

# %%
u = np.matrix(np.random.normal(size=(100, 100)))
v = np.linalg.inv(u)

# %%
np.linalg.det(u*v)
# Out:
# 0.9999999999999986

# %%
np.linalg.pinv(v)
# Out:
# matrix([[ 0.5314741 ,  0.60552869,  0.23751034, ..., -1.45029802,
#          -1.37580206, -0.69260267],
#         [ 0.92431385, -1.52285858,  2.37784454, ...,  1.43685877,
#          -0.55035085, -1.40201895],
#         [ 0.49353539, -1.59103139, -1.07403124, ...,  0.55144143,
#          -0.83354162,  1.93613331],
#         ...,
#         [-0.38448624,  2.23563631, -2.0626916 , ..., -1.21405226,
#           1.610275  , -0.29664812],
#         [ 1.48494425,  0.22687556, -0.28828584, ..., -0.15434571,
#          -0.92255394, -1.43613941],
#         [ 0.56116999,  0.00376523, -1.02120536, ...,  0.15275429,
#           0.42880906, -1.4362674 ]])
